# %% [markdown]
# # **IMPORTING LIBRARIES**

# %%
import numpy as np
import pandas as pd

# %%
# !file -bi spam.csv
# Out:
# text/csv; charset=unknown-8bit

# %% [markdown]
# # **READING DATASET**

# %%
df = pd.read_csv("spam.csv", encoding="latin-1")
df
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
# ...         ...        ...
# 5567        NaN        NaN
# 5568        NaN        NaN
# 5569        NaN        NaN
# 5570        NaN        NaN
# 5571        NaN        NaN
#
# [5572 rows x 5 columns]

# %%
df.dropna(inplace=True)

# %%
df.isnull()
# Out:
#          v1     v2  Unnamed: 2  Unnamed: 3  Unnamed: 4
# 281   False  False       False       False       False
# 1038  False  False       False       False       False
# 2255  False  False       False       False       False
# 3525  False  False       False       False       False
# 4668  False  False       False       False       False
# 5048  False  False       False       False       False

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['v1'] = le.fit_transform(df['v1'])
df['v2'] = le.fit_transform(df['v2'])

# %%
dummies=pd.get_dummies(df,dtype=int)
dummies
# Out:
#       v1  v2  Unnamed: 2_ GOD said  Unnamed: 2_ HAD A COOL NYTHO  \
# 281    0   4                     0                             0
# 1038   0   0                     0                             0
# 2255   0   1                     0                             0
# 3525   0   3                     0                             1
# 4668   0   2                     1                             0
# 5048   0   0                     0                             0
#
#       Unnamed: 2_ I don't mind  \
# 281                          0
# 1038                         0
# 2255                         1
# 3525                         0
# 4668                         0
# 5048                         0
#
#       Unnamed: 2_ the person is definitely special for u..... But if the person is so special  \
# 281                                                   1
# 1038                                                  0
# 2255                                                  0
# 3525                                                  0
# 4668                                                  0
# 5048                                                  0
#
#       Unnamed: 2_GN  Unnamed: 3_ TX 4 FONIN HON  \
# 281               0                           0
# 1038              1                           0
# 2255              0                           0
# 3525              0                           1
# 4668              0                           0
# 5048              1                           0
#
#       Unnamed: 3_ \"OH No! COMPETITION\". Who knew  \
# 281                                              0
# 1038                                             0
# 2255                                             0
# 3525                                             0
# 4668                                             1
# 5048                                             0
#
#       Unnamed: 3_ why to miss them  Unnamed: 3_GE  \
# 281                              1              0
# 1038                             0              1
# 2255                             0              0
# 3525                             0              0
# 4668                             0              0
# 5048                             0              1
#
#       Unnamed: 3_i wil tolerat.bcs ur my someone..... But  \
# 281                                                   0
# 1038                                                  0
# 2255                                                  1
# 3525                                                  0
# 4668                                                  0
# 5048                                                  0
#
#       Unnamed: 4_ CALL 2MWEN IM BK FRMCLOUD 9! J X\""  \
# 281                                                 0
# 1038                                                0
# 2255                                                0
# 3525                                                1
# 4668                                                0
# 5048                                                0
#
#       Unnamed: 4_ Never comfort me with a lie\" gud ni8 and sweet dreams"  \
# 281                                                   0
# 1038                                                  0
# 2255                                                  1
# 3525                                                  0
# 4668                                                  0
# 5048                                                  0
#
#       Unnamed: 4_ just Keep-in-touch\" gdeve.."  \
# 281                                           1
# 1038                                          0
# 2255                                          0
# 3525                                          0
# 4668                                          0
# 5048                                          0
#
#       Unnamed: 4_ one day these two will become FREINDS FOREVER!"  \
# 281                                                   0
# 1038                                                  0
# 2255                                                  0
# 3525                                                  0
# 4668                                                  1
# 5048                                                  0
#
#       Unnamed: 4_GNT:-)"
# 281                    0
# 1038                   1
# 2255                   0
# 3525                   0
# 4668                   0
# 5048                   1

# %%
X= dummies[['v1']]
y = dummies['v2']

# %%
dummies = pd.get_dummies(df[['v1', 'v2']], drop_first=False)

# %%
x_train = dummies[['v1']]
y_train = dummies['v2']

lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.05)

# %%
len(X_train)
# Out:
# 5

# %%
len(X_test)
# Out:
# 1

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.predict(X_test)
# Out:
# array([0])

# %%
lr.score(X_test,y_test)*100
# Out:
# 100.0
